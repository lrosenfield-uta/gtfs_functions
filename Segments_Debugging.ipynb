# %%
import gtfs_functions
import pandas as pd
import numpy as np
import os
import logging
import geopandas as gpd
import requests, io
import pendulum as pl
import matplotlib.pyplot as plt
import gtfs_plots
import folium
# Out:
# INFO:root:imported the dev version of gtfs_functions (rev 0314-940)
# INFO:root:imported the dev version of gtfs_plots (rev 0321-1814)

# %%
feedURI = r'Feeds\GTFS_TestBed-2025-08-06-19-02-03-gtfs.zip'
sid = gtfs_functions.Feed(feedURI).busiest_service_id
feed = gtfs_functions.Feed(feedURI, service_ids=[sid],time_windows=[0,24])
# Out:
# INFO:root:Reading "trips.txt".
# INFO:root:Feed was initiated with Service IDs. Ignoring busiest_date

# %%
stop_times = feed.stop_times
shapes = feed.shapes
req_columns = ["shape_id", "stop_sequence", "stop_id", "geometry"]
add_columns = ["route_id", "route_name","direction_id", "stop_name"]
# Out:
# INFO:root:Reading "stop_times.txt".
# INFO:root:get trips in stop_times
# INFO:root:accessing trips
# INFO:root:Reading "routes.txt".
# INFO:root:Start date is None. You should either specify a start date or set busiest_date to True.
# INFO:root:Reading "trips.txt".
# INFO:root:Including trips under the following service IDs:
# ['Service_period_1-Weekday']
# INFO:root:Reading "stop_times.txt".
# INFO:root:_trips is defined in stop_times
# INFO:root:Reading "stops.txt".
# INFO:root:computing patterns
# INFO:root:Reading "shapes.txt".

# %%
feed.routes
# Out:
#   route_id agency_id route_short_name route_long_name  route_type route_color  \
# 0    19906       UTA              455        Endloopy           3      004a97
# 1      011       UTA               11   BitterPattern           3      005BAA
# 2      002       UTA                2          Normal           3      D6393C
# 3      005       UTA                5           Loopy           3      A72051
#
#   route_text_color  route_desc  \
# 0           FFFFFF         NaN
# 1           FFFFFF         NaN
# 2           FFFFFF         NaN
# 3           FFFFFF         NaN
#
#                                            route_url  continuous_pickup  \
# 0  https://www.rideuta.com/Rider-Tools/Schedules-...                NaN
# 1                                                NaN                NaN
# 2                                                NaN                NaN
# 3                                                NaN                NaN
#
#    continuous_drop_off        route_name
# 0                  NaN      455 Endloopy
# 1                  NaN  11 BitterPattern
# 2                  NaN          2 Normal
# 3                  NaN           5 Loopy

# %%
pd.set_option("display.max_rows", 999)
df_shape_undropped = stop_times[req_columns + add_columns]
df_shape_undropped[df_shape_undropped["route_id"]=="005"]
# Out:
#       shape_id  stop_sequence stop_id                     geometry route_id  \
# 30    005-A-IB              1   13182  POINT (-111.88841 40.77064)      005
# 31    005-A-IB              2   25339  POINT (-111.88283 40.76926)      005
# 32    005-A-IB              3   19152  POINT (-111.87999 40.76924)      005
# 33    005-A-IB              4   25377  POINT (-111.87745 40.76982)      005
# 34    005-A-IB              5   19154  POINT (-111.87646 40.76942)      005
# 35    005-A-IB              6   25377  POINT (-111.87745 40.76982)      005
# 36    005-A-IB              7   25378  POINT (-111.87747 40.77266)      005
# 37    005-A-IB              8   12652   POINT (-111.87476 40.7728)      005
# 97    005-A-OB              1   12652   POINT (-111.87476 40.7728)      005
# 98    005-A-OB              2   13463    POINT (-111.8758 40.7729)      005
# 99    005-A-OB              3   25375  POINT (-111.87767 40.77254)      005
# 100   005-A-OB              4   25376  POINT (-111.87768 40.76958)      005
# 101   005-A-OB              5   19153   POINT (-111.8763 40.76928)      005
# 102   005-A-OB              6   25376  POINT (-111.87768 40.76958)      005
# 103   005-A-OB              7   13179  POINT (-111.88092 40.76943)      005
# 104   005-A-OB              8   25340  POINT (-111.88299 40.76943)      005
# 105   005-A-OB              9   13182  POINT (-111.88841 40.77064)      005
# 140   005-A-OB              1   12652   POINT (-111.87476 40.7728)      005
# 141   005-A-OB              2   13463    POINT (-111.8758 40.7729)      005
# 142   005-A-OB              3   25375  POINT (-111.87767 40.77254)      005
# 143   005-A-OB              4   25376  POINT (-111.87768 40.76958)      005
# 144   005-A-OB              5   19153   POINT (-111.8763 40.76928)      005
# 145   005-A-OB              6   25376  POINT (-111.87768 40.76958)      005
# 146   005-A-OB              7   13179  POINT (-111.88092 40.76943)      005
# 147   005-A-OB              8   25340  POINT (-111.88299 40.76943)      005
# 148   005-A-OB              9   13182  POINT (-111.88841 40.77064)      005
# 163   005-A-IB              1   13182  POINT (-111.88841 40.77064)      005
# 164   005-A-IB              2   25339  POINT (-111.88283 40.76926)      005
# 165   005-A-IB              3   19152  POINT (-111.87999 40.76924)      005
# 166   005-A-IB              4   25377  POINT (-111.87745 40.76982)      005
# 167   005-A-IB              5   19154  POINT (-111.87646 40.76942)      005
# 168   005-A-IB              6   25377  POINT (-111.87745 40.76982)      005
# 169   005-A-IB              7   25378  POINT (-111.87747 40.77266)      005
# 170   005-A-IB              8   12652   POINT (-111.87476 40.7728)      005
# 171   005-A-IB              1   13182  POINT (-111.88841 40.77064)      005
# 172   005-A-IB              2   25339  POINT (-111.88283 40.76926)      005
# 173   005-A-IB              3   19152  POINT (-111.87999 40.76924)      005
# 174   005-A-IB              4   25377  POINT (-111.87745 40.76982)      005
# 175   005-A-IB              5   19154  POINT (-111.87646 40.76942)      005
# 176   005-A-IB              6   25377  POINT (-111.87745 40.76982)      005
# 177   005-A-IB              7   25378  POINT (-111.87747 40.77266)      005
# 178   005-A-IB              8   12652   POINT (-111.87476 40.7728)      005
# 199   005-A-OB              1   12652   POINT (-111.87476 40.7728)      005
# 200   005-A-OB              2   13463    POINT (-111.8758 40.7729)      005
# 201   005-A-OB              3   25375  POINT (-111.87767 40.77254)      005
# 202   005-A-OB              4   25376  POINT (-111.87768 40.76958)      005
# 203   005-A-OB              5   19153   POINT (-111.8763 40.76928)      005
# 204   005-A-OB              6   25376  POINT (-111.87768 40.76958)      005
# 205   005-A-OB              7   13179  POINT (-111.88092 40.76943)      005
# 206   005-A-OB              8   25340  POINT (-111.88299 40.76943)      005
# 207   005-A-OB              9   13182  POINT (-111.88841 40.77064)      005
# 213   005-A-IB              1   13182  POINT (-111.88841 40.77064)      005
# 214   005-A-IB              2   25339  POINT (-111.88283 40.76926)      005
# 215   005-A-IB              3   19152  POINT (-111.87999 40.76924)      005
# 216   005-A-IB              4   25377  POINT (-111.87745 40.76982)      005
# 217   005-A-IB              5   19154  POINT (-111.87646 40.76942)      005
# 218   005-A-IB              6   25377  POINT (-111.87745 40.76982)      005
# 219   005-A-IB              7   25378  POINT (-111.87747 40.77266)      005
# 220   005-A-IB              8   12652   POINT (-111.87476 40.7728)      005
# 227   005-A-OB              1   12652   POINT (-111.87476 40.7728)      005
# 228   005-A-OB              2   13463    POINT (-111.8758 40.7729)      005
# 229   005-A-OB              3   25375  POINT (-111.87767 40.77254)      005
# 230   005-A-OB              4   25376  POINT (-111.87768 40.76958)      005
# 231   005-A-OB              5   19153   POINT (-111.8763 40.76928)      005
# 232   005-A-OB              6   25376  POINT (-111.87768 40.76958)      005
# 233   005-A-OB              7   13179  POINT (-111.88092 40.76943)      005
# 234   005-A-OB              8   25340  POINT (-111.88299 40.76943)      005
# 235   005-A-OB              9   13182  POINT (-111.88841 40.77064)      005
# 246   005-A-IB              1   13182  POINT (-111.88841 40.77064)      005
# 247   005-A-IB              2   25339  POINT (-111.88283 40.76926)      005
# 248   005-A-IB              3   19152  POINT (-111.87999 40.76924)      005
# 249   005-A-IB              4   25377  POINT (-111.87745 40.76982)      005
# 250   005-A-IB              5   19154  POINT (-111.87646 40.76942)      005
# 251   005-A-IB              6   25377  POINT (-111.87745 40.76982)      005
# 252   005-A-IB              7   25378  POINT (-111.87747 40.77266)      005
# 253   005-A-IB              8   12652   POINT (-111.87476 40.7728)      005
# 260   005-A-IB              1   13182  POINT (-111.88841 40.77064)      005
# 261   005-A-IB              2   25339  POINT (-111.88283 40.76926)      005
# 262   005-A-IB              3   19152  POINT (-111.87999 40.76924)      005
# 263   005-A-IB              4   25377  POINT (-111.87745 40.76982)      005
# 264   005-A-IB              5   19154  POINT (-111.87646 40.76942)      005
# 265   005-A-IB              6   25377  POINT (-111.87745 40.76982)      005
# 266   005-A-IB              7   25378  POINT (-111.87747 40.77266)      005
#
# 2089    5 Loopy             0           State St / 1st Ave (SB)
# 2090    5 Loopy             0  South Temple / 300 E / B St (EB)
# 2091    5 Loopy             0  South Temple / 400 E / C St (EB)
# 2092    5 Loopy             0          E St / South Temple (NB)
# 2093    5 Loopy             0  South Temple / 500 E / F St (WB)
# 2094    5 Loopy             0          E St / South Temple (NB)
# 2095    5 Loopy             0               E St / 3rd Ave (NB)
# 2096    5 Loopy             0               3rd Ave / G St (EB)
# 2114    5 Loopy             1               3rd Ave / G St (EB)
# 2115    5 Loopy             1               3rd Ave / F St (WB)
# 2116    5 Loopy             1               E St / 3rd Ave (SB)
# 2117    5 Loopy             1          E St / South Temple (SB)
# 2118    5 Loopy             1  South Temple / 500 E / F St (EB)
# 2119    5 Loopy             1          E St / South Temple (SB)
# 2120    5 Loopy             1  South Temple / 400 E / C St (WB)
# 2121    5 Loopy             1  South Temple / 300 E / B St (WB)
# 2122    5 Loopy             1           State St / 1st Ave (SB)

# %%
import timeit
import shapely.ops

# Moderately Slower, more sensible
# def prelim_parse_v1(df: pd.DataFrame):
#     df["cut_distance_stop_point"] = df[["geometry_stop", "geometry_shape"]]\
#             .apply(lambda x: x[1].project(x[0], normalized=True), axis=1)
#     df = df.where(df['cut_distance_stop_point'] >= df['cut_distance_stop_point'].cummax(),slice_interpolation_v1)
#     return df

def perform_prelim_parse(df: pd.DataFrame):
    df["cut_distance_stop_point"] = df[["geometry_stop", "geometry_shape"]]\
            .apply(lambda x: x[1].project(x[0], normalized=True), axis=1)
    #needs_correction
    df['diff_from_max'] = df['cut_distance_stop_point'] - df['cut_distance_stop_point'].cummax()
    needs_correction = df['cut_distance_stop_point'] < df['cut_distance_stop_point'].cummax()
    df.loc[needs_correction] = df.loc[needs_correction].apply(slice_interpolation, axis=1)
    #df = df.where(df['cut_distance_stop_point'] >= df['cut_distance_stop_point'].cummax(),slice_interpolation)
    df['cut_offset'] = df['cut_distance_stop_point'].shift(-1).fillna(1)
    df['geometry_shape'] = df.apply(substring_general)
    return df

# def slice_interpolation_v1(ser):
#     ser = ser.copy()
#     ser['cut_distance_stop_point'] = 1
#     return ser

def substring_general(ser):
    return shapely.ops.substring(ser['geometry_shape'],ser['cut_distance_stop_point'],['cut_offset'])

def slice_interpolation(ser):
    #ser = ser.copy()
    cdsp = ser['cut_distance_stop_point']-ser['diff_from_max']
    shape = shapely.ops.substring(ser['geometry_shape'],cdsp,1,normalized = True)
    ser['cut_distance_stop_point'] = shape.project(ser['geometry_stop'])*(1-cdsp)+cdsp
    return ser

# %%
pd.set_option("display.max_rows",100)
df_shape_stop = df_shape_undropped.drop_duplicates().sort_values('stop_sequence')
df_shape_stop = df_shape_stop.merge(shapes, on='shape_id', suffixes=("_stop", "_shape"))
#df_shape_stop["cut_distance_stop_point"]=np.nan
df_shape_stop_group = df_shape_stop.groupby("shape_id")
df_shape_stop_window = df_shape_stop_group.apply(perform_prelim_parse)
df_shape_stop_window
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File c:\Users\11925\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\indexes\base.py:3790, in Index.get_loc(self, key)
#    3789 try:
# -> 3790     return self._engine.get_loc(casted_key)
#    3791 except KeyError as err:
#
# File index.pyx:152, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:181, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\_libs\hashtable_class_helper.pxi:2606, in pandas._libs.hashtable.Int64HashTable.get_item()
#
# File pandas\_libs\hashtable_class_helper.pxi:2630, in pandas._libs.hashtable.Int64HashTable.get_item()
#
# KeyError: 0
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[178], line 6
#       4 #df_shape_stop["cut_distance_stop_point"]=np.nan
#       5 df_shape_stop_group = df_shape_stop.groupby("shape_id")
# ----> 6 df_shape_stop_window = df_shape_stop_group.apply(perform_prelim_parse)
#       7 df_shape_stop_window
#
# File c:\Users\11925\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\groupby\groupby.py:1766, in GroupBy.apply(self, func, *args, **kwargs)
#    1764 with option_context("mode.chained_assignment", None):
#    1765     try:
# -> 1766         result = self._python_apply_general(f, self._selected_obj)
#    1767     except TypeError:
#    1768         # gh-20949
#    1769         # try again, with .apply acting as a filtering
#    (...)
#    1773         # fails on *some* columns, e.g. a numeric operation
#    1774         # on a string grouper column
#    1776         return self._python_apply_general(f, self._obj_with_exclusions)
#
# File c:\Users\11925\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\groupby\groupby.py:1815, in GroupBy._python_apply_general(self, f, data, not_indexed_same, is_transform, is_agg)
#    1780 @final
#    1781 def _python_apply_general(
#    1782     self,
#    (...)
#    1787     is_agg: bool = False,
#    1788 ) -> NDFrameT:
#    1789     """
#    1790     Apply function f in python space
#    1791
#    (...)
#    1813         data after applying f
#    1814     """
# -> 1815     values, mutated = self.grouper.apply_groupwise(f, data, self.axis)
#    1816     if not_indexed_same is None:
#    1817         not_indexed_same = mutated
#
# File c:\Users\11925\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\groupby\ops.py:905, in BaseGrouper.apply_groupwise(self, f, data, axis)
#     903 # group might be modified
#     904 group_axes = group.axes
# --> 905 res = f(group)
#     906 if not mutated and not _is_indexed_like(res, group_axes, axis):
#     907     mutated = True
#
# Cell In[177], line 22, in perform_prelim_parse(df)
#      18 #df = df.where(df['cut_distance_stop_point'] >= df['cut_distance_stop_point'].cummax(),slice_interpolation)
#      19 df['cut_offset'] = df['cut_distance_stop_point'].shift(-1).fillna(1)
#      20 df['geometry_shape'] = df[[
#      21     'geometry_shape', 'cut_distance_stop_point','cut_offset'
# ---> 22     ]].apply(
#      23         lambda x: shapely.ops.substring(x[0],x[1],normalized=True))
#      24 return df
#
# File c:\Users\11925\AppData\Local\Programs\Python\Python312\Lib\site-packages\geopandas\geodataframe.py:1991, in GeoDataFrame.apply(self, func, axis, raw, result_type, args, **kwargs)
#    1981 @doc(pd.DataFrame)
#    1982 def apply(
#    1983     self,
#    (...)
#    1989     **kwargs,
#    1990 ):
# -> 1991     result = super().apply(
#    1992         func, axis=axis, raw=raw, result_type=result_type, args=args, **kwargs
#    1993     )
#    1994     # Reconstruct gdf if it was lost by apply
#    1995     if (
#    1996         isinstance(result, DataFrame)
#    1997         and self._geometry_column_name in result.columns
#    1998     ):
#    1999         # axis=1 apply will split GeometryDType to object, try and cast back
#
# File c:\Users\11925\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\frame.py:10037, in DataFrame.apply(self, func, axis, raw, result_type, args, by_row, **kwargs)
#   10025 from pandas.core.apply import frame_apply
#   10027 op = frame_apply(
#   10028     self,
#   10029     func=func,
#    (...)
#   10035     kwargs=kwargs,
#   10036 )
# > 10037 return op.apply().__finalize__(self, method="apply")
#
# File c:\Users\11925\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\apply.py:837, in FrameApply.apply(self)
#     834 elif self.raw:
#     835     return self.apply_raw()
# --> 837 return self.apply_standard()
#
# File c:\Users\11925\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\apply.py:963, in FrameApply.apply_standard(self)
#     962 def apply_standard(self):
# --> 963     results, res_index = self.apply_series_generator()
#     965     # wrap results
#     966     return self.wrap_results(results, res_index)
#
# File c:\Users\11925\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\apply.py:979, in FrameApply.apply_series_generator(self)
#     976 with option_context("mode.chained_assignment", None):
#     977     for i, v in enumerate(series_gen):
#     978         # ignore SettingWithCopy here in case the user mutates
# --> 979         results[i] = self.func(v, *self.args, **self.kwargs)
#     980         if isinstance(results[i], ABCSeries):
#     981             # If we have a view on v, we need to make a copy because
#     982             #  series_generator will swap out the underlying data
#     983             results[i] = results[i].copy(deep=False)
#
# Cell In[177], line 23, in perform_prelim_parse.<locals>.<lambda>(x)
#      18 #df = df.where(df['cut_distance_stop_point'] >= df['cut_distance_stop_point'].cummax(),slice_interpolation)
#      19 df['cut_offset'] = df['cut_distance_stop_point'].shift(-1).fillna(1)
#      20 df['geometry_shape'] = df[[
#      21     'geometry_shape', 'cut_distance_stop_point','cut_offset'
#      22     ]].apply(
# ---> 23         lambda x: shapely.ops.substring(x[0],x[1],normalized=True))
#      24 return df
#
# File c:\Users\11925\AppData\Local\Programs\Python\Python312\Lib\site-packages\geopandas\geoseries.py:779, in GeoSeries.__getitem__(self, key)
#     778 def __getitem__(self, key):
# --> 779     return self._wrapped_pandas_method("__getitem__", key)
#
# File c:\Users\11925\AppData\Local\Programs\Python\Python312\Lib\site-packages\geopandas\geoseries.py:772, in GeoSeries._wrapped_pandas_method(self, mtd, *args, **kwargs)
#     770 def _wrapped_pandas_method(self, mtd, *args, **kwargs):
#     771     """Wrap a generic pandas method to ensure it returns a GeoSeries."""
# --> 772     val = getattr(super(), mtd)(*args, **kwargs)
#     773     if type(val) is Series:
#     774         val.__class__ = GeoSeries
#
# File c:\Users\11925\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\series.py:1040, in Series.__getitem__(self, key)
#    1037     return self._values[key]
#    1039 elif key_is_scalar:
# -> 1040     return self._get_value(key)
#    1042 # Convert generator to list before going through hashable part
#    1043 # (We will iterate through the generator there to check for slices)
#    1044 if is_iterator(key):
#
# File c:\Users\11925\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\series.py:1156, in Series._get_value(self, label, takeable)
#    1153     return self._values[label]
#    1155 # Similar to Index.get_value, but we do not fall back to positional
# -> 1156 loc = self.index.get_loc(label)
#    1158 if is_integer(loc):
#    1159     return self._values[loc]
#
# File c:\Users\11925\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\indexes\base.py:3797, in Index.get_loc(self, key)
#    3792     if isinstance(casted_key, slice) or (
#    3793         isinstance(casted_key, abc.Iterable)
#    3794         and any(isinstance(x, slice) for x in casted_key)
#    3795     ):
#    3796         raise InvalidIndexError(key)
# -> 3797     raise KeyError(key) from err
#    3798 except TypeError:
#    3799     # If we have a listlike key, _check_indexing_error will raise
#    3800     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3801     #  the TypeError.
#    3802     self._check_indexing_error(key)
#
# KeyError: 0

# %%
dfr = df_shape_stop_group.get_group('005-A-IB')
dfp = perform_prelim_parse(dfr)
ser = dfp.iloc[5]
ser
cdsp = ser['cut_distance_stop_point']+0.1
ser['geometry_shape'] = shapely.ops.substring(ser['geometry_shape'],cdsp,1,normalized = True)
ser['cut_distance_stop_point'] = ser['geometry_shape'].project(ser['geometry_stop'])
ser
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File c:\Users\11925\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\indexes\base.py:3790, in Index.get_loc(self, key)
#    3789 try:
# -> 3790     return self._engine.get_loc(casted_key)
#    3791 except KeyError as err:
#
# File index.pyx:152, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:181, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\_libs\hashtable_class_helper.pxi:2606, in pandas._libs.hashtable.Int64HashTable.get_item()
#
# File pandas\_libs\hashtable_class_helper.pxi:2630, in pandas._libs.hashtable.Int64HashTable.get_item()
#
# KeyError: 0
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[169], line 2
#       1 dfr = df_shape_stop_group.get_group('005-A-IB')
# ----> 2 dfp = perform_prelim_parse(dfr)
#       3 ser = dfp.iloc[5]
#       4 ser
#
# Cell In[167], line 22, in perform_prelim_parse(df)
#      18 #df = df.where(df['cut_distance_stop_point'] >= df['cut_distance_stop_point'].cummax(),slice_interpolation)
#      19 df['cut_offset'] = df['cut_distance_stop_point'].shift(-1)
#      20 df['geometry_shape'] = df[[
#      21     'geometry_shape', 'cut_distance_stop_point','cut_offset'
# ---> 22     ]].apply(
#      23         lambda x: shapely.ops.substring(x[0],x[1],x[2],normalized=True))
#      24 return df
#
# File c:\Users\11925\AppData\Local\Programs\Python\Python312\Lib\site-packages\geopandas\geodataframe.py:1991, in GeoDataFrame.apply(self, func, axis, raw, result_type, args, **kwargs)
#    1981 @doc(pd.DataFrame)
#    1982 def apply(
#    1983     self,
#    (...)
#    1989     **kwargs,
#    1990 ):
# -> 1991     result = super().apply(
#    1992         func, axis=axis, raw=raw, result_type=result_type, args=args, **kwargs
#    1993     )
#    1994     # Reconstruct gdf if it was lost by apply
#    1995     if (
#    1996         isinstance(result, DataFrame)
#    1997         and self._geometry_column_name in result.columns
#    1998     ):
#    1999         # axis=1 apply will split GeometryDType to object, try and cast back
#
# File c:\Users\11925\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\frame.py:10037, in DataFrame.apply(self, func, axis, raw, result_type, args, by_row, **kwargs)
#   10025 from pandas.core.apply import frame_apply
#   10027 op = frame_apply(
#   10028     self,
#   10029     func=func,
#    (...)
#   10035     kwargs=kwargs,
#   10036 )
# > 10037 return op.apply().__finalize__(self, method="apply")
#
# File c:\Users\11925\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\apply.py:837, in FrameApply.apply(self)
#     834 elif self.raw:
#     835     return self.apply_raw()
# --> 837 return self.apply_standard()
#
# File c:\Users\11925\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\apply.py:963, in FrameApply.apply_standard(self)
#     962 def apply_standard(self):
# --> 963     results, res_index = self.apply_series_generator()
#     965     # wrap results
#     966     return self.wrap_results(results, res_index)
#
# File c:\Users\11925\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\apply.py:979, in FrameApply.apply_series_generator(self)
#     976 with option_context("mode.chained_assignment", None):
#     977     for i, v in enumerate(series_gen):
#     978         # ignore SettingWithCopy here in case the user mutates
# --> 979         results[i] = self.func(v, *self.args, **self.kwargs)
#     980         if isinstance(results[i], ABCSeries):
#     981             # If we have a view on v, we need to make a copy because
#     982             #  series_generator will swap out the underlying data
#     983             results[i] = results[i].copy(deep=False)
#
# Cell In[167], line 23, in perform_prelim_parse.<locals>.<lambda>(x)
#      18 #df = df.where(df['cut_distance_stop_point'] >= df['cut_distance_stop_point'].cummax(),slice_interpolation)
#      19 df['cut_offset'] = df['cut_distance_stop_point'].shift(-1)
#      20 df['geometry_shape'] = df[[
#      21     'geometry_shape', 'cut_distance_stop_point','cut_offset'
#      22     ]].apply(
# ---> 23         lambda x: shapely.ops.substring(x[0],x[1],x[2],normalized=True))
#      24 return df
#
# File c:\Users\11925\AppData\Local\Programs\Python\Python312\Lib\site-packages\geopandas\geoseries.py:779, in GeoSeries.__getitem__(self, key)
#     778 def __getitem__(self, key):
# --> 779     return self._wrapped_pandas_method("__getitem__", key)
#
# File c:\Users\11925\AppData\Local\Programs\Python\Python312\Lib\site-packages\geopandas\geoseries.py:772, in GeoSeries._wrapped_pandas_method(self, mtd, *args, **kwargs)
#     770 def _wrapped_pandas_method(self, mtd, *args, **kwargs):
#     771     """Wrap a generic pandas method to ensure it returns a GeoSeries."""
# --> 772     val = getattr(super(), mtd)(*args, **kwargs)
#     773     if type(val) is Series:
#     774         val.__class__ = GeoSeries
#
# File c:\Users\11925\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\series.py:1040, in Series.__getitem__(self, key)
#    1037     return self._values[key]
#    1039 elif key_is_scalar:
# -> 1040     return self._get_value(key)
#    1042 # Convert generator to list before going through hashable part
#    1043 # (We will iterate through the generator there to check for slices)
#    1044 if is_iterator(key):
#
# File c:\Users\11925\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\series.py:1156, in Series._get_value(self, label, takeable)
#    1153     return self._values[label]
#    1155 # Similar to Index.get_value, but we do not fall back to positional
# -> 1156 loc = self.index.get_loc(label)
#    1158 if is_integer(loc):
#    1159     return self._values[loc]
#
# File c:\Users\11925\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\indexes\base.py:3797, in Index.get_loc(self, key)
#    3792     if isinstance(casted_key, slice) or (
#    3793         isinstance(casted_key, abc.Iterable)
#    3794         and any(isinstance(x, slice) for x in casted_key)
#    3795     ):
#    3796         raise InvalidIndexError(key)
# -> 3797     raise KeyError(key) from err
#    3798 except TypeError:
#    3799     # If we have a listlike key, _check_indexing_error will raise
#    3800     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3801     #  the TypeError.
#    3802     self._check_indexing_error(key)
#
# KeyError: 0

# %%
shapes
# Out:
#      shape_id                                           geometry
# 0    002-A-IB  LINESTRING (-111.88831 40.76587, -111.8883 40....
# 1    002-A-OB  LINESTRING (-111.87706 40.76501, -111.87709 40...
# 2    005-A-IB  LINESTRING (-111.88833 40.77066, -111.88834 40...
# 3    005-A-OB  LINESTRING (-111.87468 40.77284, -111.87593 40...
# 4    011-A-IB  LINESTRING (-111.87991 40.77965, -111.87981 40...
# 5    011-A-OB  LINESTRING (-111.86287 40.78151, -111.86299 40...
# 6    011-B-IB  LINESTRING (-111.87999 40.77965, -111.87981 40...
# 7    011-B-OB  LINESTRING (-111.8629 40.78153, -111.86299 40....
# 8  19906-A-IB  LINESTRING (-111.83408 40.75556, -111.83373 40...
# 9  19906-A-OB  LINESTRING (-111.83156 40.75665, -111.82894 40...

# %%
df_shape_stop_2 = df_shape_stop.merge(shapes, on="shape_id", suffixes=("_stop", "_shape"))
flt = df_shape_stop[df_shape_stop["route_id"]=="005"]
f=folium.Figure(width=500, height=300)
m = gtfs_plots.map_gdf(flt,variable="stop_sequence",tooltip_var=['stop_sequence'])
m.add_to(f)
f
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[151], line 4
#       2 flt = df_shape_stop[df_shape_stop["route_id"]=="005"]
#       3 f=folium.Figure(width=500, height=300)
# ----> 4 m = gtfs_plots.map_gdf(flt,variable="stop_sequence",tooltip_var=['stop_sequence'])
#       5 m.add_to(f)
#       6 f
#
# File c:\Users\11925\Documents\Tools\gtfs_functions\gtfs_plots.py:25, in map_gdf(gdf, variable, colors, tooltip_var, tooltip_labels, breaks)
#      23 gdf.reset_index(inplace=True, drop=True)
#      24 # Look for the center of the map
# ---> 25 minx, miny, maxx, maxy = gdf.geometry.total_bounds
#      27 centroid_lat = miny + (maxy - miny)/2
#      28 centroid_lon = minx + (maxx - minx)/2
#
# File c:\Users\11925\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\generic.py:6204, in NDFrame.__getattr__(self, name)
#    6197 if (
#    6198     name not in self._internal_names_set
#    6199     and name not in self._metadata
#    6200     and name not in self._accessors
#    6201     and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    6202 ):
#    6203     return self[name]
# -> 6204 return object.__getattribute__(self, name)
#
# File c:\Users\11925\AppData\Local\Programs\Python\Python312\Lib\site-packages\geopandas\geodataframe.py:287, in GeoDataFrame._get_geometry(self)
#     280     else:
#     281         msg += (
#     282             "\nThere are no existing columns with geometry data type. You can "
#     283             "add a geometry column as the active geometry column with "
#     284             "df.set_geometry. "
#     285         )
# --> 287     raise AttributeError(msg)
#     288 return self[self._geometry_column_name]
#
# AttributeError: You are calling a geospatial method on the GeoDataFrame, but the active geometry column ('geometry') is not present.
# There are columns with geometry data type (['geometry_stop', 'geometry_shape']), and you can either set one as the active geometry with df.set_geometry("name") or access the column as a GeoSeries (df["name"]) and call the method directly on it.

# %%
df_shape_stop_2["cut_distance_stop_point"] = df_shape_stop_2[["geometry_stop", "geometry_shape"]]\
            .apply(lambda x: x[1].project(x[0], normalized=True), axis=1)
flt = df_shape_stop_2[df_shape_stop_2["route_id"]=="011"]
flt =flt[flt["direction_id"]==0]
flt = flt.set_geometry("geometry_stop")
flt
flt
# Out:
#     shape_id  stop_sequence stop_id                geometry_stop route_id  \
# 5   011-B-IB              1    3569   POINT (-111.87992 40.7796)      011
# 6   011-B-IB              2   15191   POINT (-111.8776 40.77957)      011
# 7   011-B-IB              3   15205  POINT (-111.87752 40.78067)      011
# 8   011-B-IB              4   15206  POINT (-111.87751 40.78177)      011
# 9   011-B-IB              5   25268   POINT (-111.8747 40.78182)      011
# 10  011-B-IB              6   15210  POINT (-111.87096 40.78183)      011
# 11  011-B-IB              7   15211  POINT (-111.86871 40.78185)      011
# 12  011-B-IB              8    2778  POINT (-111.86667 40.78182)      011
# 13  011-B-IB              9   15212  POINT (-111.86296 40.78148)      011
# 14  011-A-IB              1    3569   POINT (-111.87992 40.7796)      011
# 15  011-A-IB              2   15191   POINT (-111.8776 40.77957)      011
# 16  011-A-IB              3   25382  POINT (-111.87475 40.77953)      011
# 17  011-A-IB              4   25383  POINT (-111.87129 40.77955)      011
# 18  011-A-IB              5   25384  POINT (-111.86725 40.77954)      011
# 19  011-A-IB              6    2778  POINT (-111.86667 40.78182)      011
# 20  011-A-IB              7   15212  POINT (-111.86296 40.78148)      011
#
#           route_name  direction_id                         stop_name  \
# 5   11 BitterPattern             0       9th Ave / LDS Hospital (EB)
# 6   11 BitterPattern             0               9th Ave / E St (EB)
# 7   11 BitterPattern             0              E St / 10th Ave (NB)
# 8   11 BitterPattern             0              E St / 11th Ave (NB)
# 9   11 BitterPattern             0              11th Ave / G St (EB)
# 10  11 BitterPattern             0              11th Ave / I St (EB)
# 11  11 BitterPattern             0              11th Ave / K St (EB)
# 12  11 BitterPattern             0              11th Ave / L St (EB)
# 13  11 BitterPattern             0  11th Ave / Terrace Hills Dr (EB)
# 14  11 BitterPattern             0       9th Ave / LDS Hospital (EB)
# 15  11 BitterPattern             0               9th Ave / E St (EB)
# 16  11 BitterPattern             0               9th Ave / G St (EB)
# 17  11 BitterPattern             0               9th Ave / I St (EB)
# 18  11 BitterPattern             0               9th Ave / L St (EB)
# 19  11 BitterPattern             0              11th Ave / L St (EB)
# 20  11 BitterPattern             0  11th Ave / Terrace Hills Dr (EB)
#
#                                        geometry_shape  cut_distance_stop_point
# 5   LINESTRING (-111.87999 40.77965, -111.87981 40...                 0.003804
# 6   LINESTRING (-111.87999 40.77965, -111.87981 40...                 0.122882
# 7   LINESTRING (-111.87999 40.77965, -111.87981 40...                 0.177219
# 8   LINESTRING (-111.87999 40.77965, -111.87981 40...                 0.234147
# 9   LINESTRING (-111.87999 40.77965, -111.87981 40...                 0.388729
# 10  LINESTRING (-111.87999 40.77965, -111.87981 40...                 0.580760
# 11  LINESTRING (-111.87999 40.77965, -111.87981 40...                 0.696606
# 12  LINESTRING (-111.87999 40.77965, -111.87981 40...                 0.801354
# 13  LINESTRING (-111.87999 40.77965, -111.87981 40...                 0.995839
# 14  LINESTRING (-111.87991 40.77965, -111.87981 40...                 0.000000
# 15  LINESTRING (-111.87991 40.77965, -111.87981 40...                 0.119284
# 16  LINESTRING (-111.87991 40.77965, -111.87981 40...                 0.266429
# 17  LINESTRING (-111.87991 40.77965, -111.87981 40...                 0.445079
# 18  LINESTRING (-111.87991 40.77965, -111.87981 40...                 0.653664
# 19  LINESTRING (-111.87991 40.77965, -111.87981 40...                 0.801173
# 20  LINESTRING (-111.87991 40.77965, -111.87981 40...                 0.996362

# %%
f=folium.Figure(width=500, height=300)
m=folium.Map(location=[40.775,-111.935],
                 tiles='cartodbpositron', zoom_start=15)
pointalong = flt.iloc[1].geometry_shape.interpolate(0.2, normalized=True)
cir=folium.CircleMarker([pointalong.y,pointalong.x],radius=3)
cir.add_to(m)
m.add_to(f)
f
# Out:
# <iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_1154b056c36360fae58e919d6ab16ee4 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_1154b056c36360fae58e919d6ab16ee4&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_1154b056c36360fae58e919d6ab16ee4 = L.map(
#                 &quot;map_1154b056c36360fae58e919d6ab16ee4&quot;,
#                 {
#                     center: [40.775, -111.935],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 15,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_03e45c349c0d0bbfda5b9d8d206583fc = L.tileLayer(
#                 &quot;https://{s}.basemaps.cartocdn.com/light_all/{z}/{x}/{y}{r}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors \u0026copy; \u003ca href=\&quot;https://carto.com/attributions\&quot;\u003eCARTO\u003c/a\u003e&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 20, &quot;maxZoom&quot;: 20, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abcd&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_03e45c349c0d0bbfda5b9d8d206583fc.addTo(map_1154b056c36360fae58e919d6ab16ee4);
#
#
#             var circle_marker_f883f4cb7df6e1292dc21b2712748375 = L.circleMarker(
#                 [40.771825287632545, -111.93927],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#3388ff&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;#3388ff&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 3, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_1154b056c36360fae58e919d6ab16ee4);
#
# &lt;/script&gt;
# &lt;/html&gt;" width="500" height="300"style="border:none !important;" "allowfullscreen" "webkitallowfullscreen" "mozallowfullscreen"></iframe>

# %%
pointalong.xy
# Out:
# (array('d', [-111.93928]), array('d', [40.772872958516366]))
